# %%
# %matplotlib inline
import os

import geopandas as gpd
import matplotlib.pyplot as plt

import mplleaflet

# %%
df = gpd.read_file('schisto_wgs84.shp')

# %%
ax = df.plot()

# %%
mplleaflet.display(fig=ax.figure, crs=df.crs)
# Out:
# <head>
#   <link rel="stylesheet" href="http://cdn.leafletjs.com/leaflet-0.7.1/leaflet.css" />
#   <script src="http://cdn.leafletjs.com/leaflet-0.7.1/leaflet.js"></script>
#   <style>
#     #map5e26e7ac22414c5db9f289fc7b9b0f15 {
#       height:320.0px;
#     }
#   </style>
# </head>
# <body>
#   <div id="map5e26e7ac22414c5db9f289fc7b9b0f15"></div>
# <script text="text/javascript">
# func5e26e7ac22414c5db9f289fc7b9b0f15 = function() {
# var map = L.map('map5e26e7ac22414c5db9f289fc7b9b0f15');
# L.tileLayer(
#   "http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
#   {maxZoom:19, attribution: '<a href="https://github.com/jwass/mplleaflet">mplleaflet</a> | Map data (c) <a href="http://openstreetmap.org">OpenStreetMap</a> contributors'}).addTo(map);
# ...
